# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
##1

def mean(arr):
  sum=0
  mean=0
  for i in arr:
    sum+=i
  mean=sum/len(arr)
  return mean

def variance(arr):
  s=0
  var=0
  for i in arr:
    s+=(i-mean(arr))**2
    var=s/len(arr)
  return var

# %%
data = sns.load_dataset(name='iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sl=data['sepal_length'].values

print("Mean of Sepal Length : ",mean(sl))
print("Variance of Sepal Length : ",variance(sl))
# Out:
# Mean of Sepal Length :  5.843333333333335
# Variance of Sepal Length :  0.6811222222222222

# %%
sw=data['sepal_width'].values

print("Mean of Sepal Width : ",mean(sw))
print("Variance of Sepal Width : ",variance(sw))
# Out:
# Mean of Sepal Width :  3.057333333333334
# Variance of Sepal Width :  0.1887128888888887

# %%
pl=data['petal_length'].values

print("Mean of Petal Length : ",mean(pl))
print("Variance of Petal Length : ",variance(pl))
# Out:
# Mean of Petal Length :  3.7580000000000027
# Variance of Petal Length :  3.0955026666666674

# %%
pw=data['petal_width'].values

print("Mean of Petal Width : ",mean(pw))
print("Variance of Petal Width : ",variance(pw))
# Out:
# Mean of Petal Width :  1.199333333333334
# Variance of Petal Width :  0.5771328888888888

# %%
def covariance(x,y):
  ex=mean(x)
  ey=mean(y)

  num=sum((x[i]-ex)*(y[i]-ey) for i in range(len(x)))
  cov=num/len(x)
  return cov

n=data.shape[0]

def correlation_coeff(x,y):
  cov=covariance(x,y)
  v1=variance(x)
  v2=variance(y)
  cc=cov/(np.sqrt(v1)*np.sqrt(v2))
  return cc

# %%
##2

cc=[]
columns= data.columns

for x in columns[:-1]:
  for y in columns[:-1]:
    if x!=y:
      cor_coeff= correlation_coeff((data[x].to_numpy()), data[y].to_numpy())
      if (x,y,cor_coeff) and (y,x,cor_coeff) not in cc:
        cc.append((x,y,cor_coeff))

for coeff in sorted(cc,key= lambda x: x[2], reverse = True):
    print(f"{coeff[0]} and {coeff[1]}: {coeff[2]}")
# Out:
# petal_length and petal_width: 0.9628654314027956
# sepal_length and petal_length: 0.8717537758865828
# sepal_length and petal_width: 0.8179411262715758
# sepal_length and sepal_width: -0.11756978413300205
# sepal_width and petal_width: -0.3661259325364395
# sepal_width and petal_length: -0.42844010433054003

# %%
D=data.iloc[:, :4].to_numpy()

plt.figure(figsize=(15, 3))
plt.subplot(1, 3, 1)
plt.scatter(D[:, 0], D[:, 1], c='orange', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.subplot(1, 3, 2)
plt.scatter(D[:, 0], D[:, 2], c='purple', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.subplot(1, 3, 3)
plt.scatter(D[:, 0], D[:, 3], c='green', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('petal_width')
plt.suptitle("CORRELATION BETWEEN ATTRIBUTES",fontsize=14)
plt.show()

print()

plt.figure(figsize=(15, 3))
plt.subplot(1, 3, 1)
plt.scatter(D[:, 1], D[:, 3], c='blue', s=60, alpha=0.4)
plt.xlabel('sepal_width')
plt.ylabel('petal_width')
plt.subplot(1, 3, 2)
plt.scatter(D[:, 1], D[:, 2], c='pink', s=60, alpha=0.4)
plt.xlabel('sepal_width')
plt.ylabel('petal_length')
plt.subplot(1, 3, 3)
plt.scatter(D[:, 2], D[:, 3], c='red', s=60, alpha=0.4)
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
X = data[data['species']=='setosa']
X
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
##3a

cc1=[]
columns= X.columns

for x in columns[:-1]:
  for y in columns[:-1]:
    if x!=y:
      cor_coeff= correlation_coeff((X[x].to_numpy()), X[y].to_numpy())
      if (x,y,cor_coeff) and (y,x,cor_coeff) not in cc1:
        cc1.append((x,y,cor_coeff))

for coeff in sorted(cc1,key= lambda x: x[2], reverse = True):
    print(f"{coeff[0]} and {coeff[1]}: {coeff[2]}")
# Out:
# sepal_length and sepal_width: 0.7425466856651597
# petal_length and petal_width: 0.3316300408041185
# sepal_length and petal_width: 0.2780983529359694
# sepal_length and petal_length: 0.26717575886875716
# sepal_width and petal_width: 0.23275201136287943
# sepal_width and petal_length: 0.17769996678227074

# %%
X = data[data['species']=='setosa'].iloc[:, :4].to_numpy()

plt.figure(figsize=(15, 3))
plt.subplot(1, 3, 1)
plt.scatter(X[:, 0], X[:, 1], c='orange', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.subplot(1, 3, 2)
plt.scatter(X[:, 0], X[:, 2], c='purple', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.subplot(1, 3, 3)
plt.scatter(X[:, 0], X[:, 3], c='green', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('petal_width')
plt.suptitle("CORRELATION FOR SPECIES 'SETOSA'",fontsize=14)
plt.show()

print()

plt.figure(figsize=(15, 3))
plt.subplot(1, 3, 1)
plt.scatter(X[:, 1], X[:, 3], c='blue', s=60, alpha=0.4)
plt.xlabel('sepal_width')
plt.ylabel('petal_width')
plt.subplot(1, 3, 2)
plt.scatter(X[:, 1], X[:, 2], c='pink', s=60, alpha=0.4)
plt.xlabel('sepal_width')
plt.ylabel('petal_length')
plt.subplot(1, 3, 3)
plt.scatter(X[:, 2], X[:, 3], c='red', s=60, alpha=0.4)
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
Y=data[data['species']=='versicolor']
Y
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
##3b

cc2=[]
columns= Y.columns

for x in columns[:-1]:
  for y in columns[:-1]:
    if x!=y:
      cor_coeff= correlation_coeff((Y[x].to_numpy()),Y[y].to_numpy())
      if (x,y,cor_coeff) and (y,x,cor_coeff) not in cc2:
        cc2.append((x,y,cor_coeff))

for coeff in sorted(cc2,key= lambda x: x[2], reverse = True):
    print(f"{coeff[0]} and {coeff[1]}: {coeff[2]}")
# Out:
# petal_length and petal_width: 0.7866680885228168
# sepal_length and petal_length: 0.754048958592016
# sepal_width and petal_width: 0.6639987200241115
# sepal_width and petal_length: 0.560522091692982
# sepal_length and petal_width: 0.5464610715986299
# sepal_length and sepal_width: 0.5259107172828243

# %%
Y = data[data['species']=='versicolor'].iloc[:, :4].to_numpy()

plt.figure(figsize=(15, 3))
plt.subplot(1, 3, 1)
plt.scatter(Y[:, 0], Y[:, 1], c='orange', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.subplot(1, 3, 2)
plt.scatter(Y[:, 0], Y[:, 2], c='purple', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.subplot(1, 3, 3)
plt.scatter(Y[:, 0], Y[:, 3], c='green', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('petal_width')
plt.suptitle("CORRELATION FOR SPECIES 'VERSICOLOR'",fontsize=14)
plt.show()

print()

plt.figure(figsize=(15, 3))
plt.subplot(1, 3, 1)
plt.scatter(Y[:, 1], Y[:, 3], c='blue', s=60, alpha=0.4)
plt.xlabel('sepal_width')
plt.ylabel('petal_width')
plt.subplot(1, 3, 2)
plt.scatter(Y[:, 1], Y[:, 2], c='pink', s=60, alpha=0.4)
plt.xlabel('sepal_width')
plt.ylabel('petal_length')
plt.subplot(1, 3, 3)
plt.scatter(Y[:, 2], Y[:, 3], c='red', s=60, alpha=0.4)
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
Z=data[data['species']=='virginica']
Z
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
##3c

cc3=[]
columns= Z.columns

for x in columns[:-1]:
  for y in columns[:-1]:
    if x!=y:
      cor_coeff= correlation_coeff((Z[x].to_numpy()), Z[y].to_numpy())
      if (x,y,cor_coeff) and (y,x,cor_coeff) not in cc3:
        cc3.append((x,y,cor_coeff))

for coeff in sorted(cc3,key= lambda x: x[2], reverse = True):
    print(f"{coeff[0]} and {coeff[1]}: {coeff[2]}")
# Out:
# sepal_length and petal_length: 0.8642247329355761
# sepal_width and petal_width: 0.5377280262661887
# sepal_length and sepal_width: 0.45722781639411275
# sepal_width and petal_length: 0.4010445773427851
# petal_length and petal_width: 0.32210821590031824
# sepal_length and petal_width: 0.2811077091573195

# %%
Z = data[data['species']=='virginica'].iloc[:, :4].to_numpy()

plt.figure(figsize=(15, 3))
plt.subplot(1, 3, 1)
plt.scatter(Z[:, 0], Z[:, 1], c='orange', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.subplot(1, 3, 2)
plt.scatter(Z[:, 0], Z[:, 2], c='purple', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.subplot(1, 3, 3)
plt.scatter(Z[:, 0], Z[:, 3], c='green', s=60, alpha=0.4)
plt.xlabel('sepal_length')
plt.ylabel('petal_width')
plt.suptitle("CORRELATION FOR SPECIES 'VIRGINICA'",fontsize=14)
plt.show()

print()

plt.figure(figsize=(15, 3))
plt.subplot(1, 3, 1)
plt.scatter(Z[:, 1], Z[:, 3], c='blue', s=60, alpha=0.4)
plt.xlabel('sepal_width')
plt.ylabel('petal_width')
plt.subplot(1, 3, 2)
plt.scatter(Z[:, 1], Z[:, 2], c='pink', s=60, alpha=0.4)
plt.xlabel('sepal_width')
plt.ylabel('petal_length')
plt.subplot(1, 3, 3)
plt.scatter(Z[:, 2], Z[:, 3], c='red', s=60, alpha=0.4)
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()
